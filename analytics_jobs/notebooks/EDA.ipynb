# %%
import  pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('./inputs/spotify.csv')

df
# Out:
#                                  Track URI  \
# 0     spotify:track:1XAZlnVtthcDZt2NI1Dtxo
# 1     spotify:track:6a8GbQIlV8HBUW3c6Uk9PH
# 2     spotify:track:70XtWbcVZcpaOddJftMcVi
# 3     spotify:track:1NXUWyPJk5kO6DQJ5t7bDu
# 4     spotify:track:72WZtWs6V7uu3aMgMmEkYe
# ...                                    ...
# 9994  spotify:track:3kcKlOkQQEPVwxwljbGJ5p
# 9995  spotify:track:5k9QrzJFDAp5cXVdzAi02f
# 9996  spotify:track:5ydeCNaWDmFbu4zl0roPAH
# 9997  spotify:track:0zKbDrEXKpnExhGQRe9dxt
# 9998  spotify:track:3iKuIfvoU50eww6EVzNqHo
#
#                                              Track Name  \
# 0               Justified & Ancient - Stand by the Jams
# 1                       I Know You Want Me (Calle Ocho)
# 2                    From the Bottom of My Broken Heart
# 3                      Apeman - 2014 Remastered Version
# 4                    You Can't Always Get What You Want
# ...                                                 ...
# ...

# %%
df.describe()
# Out:
#        Disc Number  Track Number  Track Duration (ms)   Popularity  \
# count  9999.000000   9999.000000         9.999000e+03  9999.000000
# mean      1.035104      4.957096         2.248150e+05    37.624662
# std       0.327856      5.502810         5.410012e+04    29.460808
# min       0.000000      0.000000         0.000000e+00     0.000000
# 25%       1.000000      1.000000         1.925795e+05     0.000000
# 50%       1.000000      3.000000         2.199060e+05    42.000000
# 75%       1.000000      7.000000         2.502600e+05    64.000000
# max      15.000000     93.000000         1.561133e+06    98.000000
#
#        Danceability       Energy          Key     Loudness         Mode  \
# count   9997.000000  9997.000000  9997.000000  9997.000000  9997.000000
# mean       0.607925     0.683281     5.167750    -7.269217     0.698410
# std        0.145869     0.191131     3.578392     3.281731     0.458971
# min        0.000000     0.000020     0.000000   -29.368000     0.000000
# ...

# %%
df['Track Name'].nunique()
# Out:
# 8258

# %%
df['Artist Name(s)'].nunique()
# Out:
# 4129

# %%
df.groupby(['Artist Name(s)'])['Track Name'].nunique().reset_index().sort_values(['Track Name'], ascending=False)
# Out:
#                            Artist Name(s)  Track Name
# 1124                        Elvis Presley          41
# 3471                          The Beatles          38
# 2278                              Madonna          37
# 3424                         Taylor Swift          36
# 2704                                 P!nk          35
# ...                                   ...         ...
# 1662            Jarryd James, Julia Stone           1
# 1665               Jason Derulo, 2 Chainz           1
# 1666  Jason Derulo, Adam Levine, Maroon 5           1
# 1667         Jason Derulo, French Montana           1
# 4128               will.i.am, Nicki Minaj           1
#
# [4129 rows x 2 columns]

# %%
df['Release Dates'] = pd.to_datetime(df['Album Release Date'],format='yyyy-mm-dd')
# df['Release Dates'].max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Celda 7 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=0'>1</a> df['Release Dates'] = pd.to_datetime(df['Album Release Date'],format='yyyy-mm-dd')
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=1'>2</a> # df['Release Dates'].max()
#
# File ~/Documents/proyectos/gclolud_example/venv/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
for x in df['Album Release Date'].unique():
    print(x)
# Out:
# 1992-08-03
# 2009-10-23
# 1999-01-12
# 2014-10-20
# 1969-12-05
# 1977-02-04
# 2018-07-12
# 1997-01-01
# 1981
# 2016-09-23
# 2002-09-10
# 2002-11-12
# 2003
# 1978-03-31
# 2014-06-21
# 1976-01-01
# 2016-01-01
# 2016-10-01
# 2012-03-20
# 2011-03-08
# 2012
# 2015-09-25
# 1978-08-12
# 2020-04-01
# 2016-03-11
# 2008-10-07
# 2009-10-19
# 2016-05-20
# 2010-01-01
# 2015-03-06
# 2002
# 1972-07-21
# 1987
# 2013-08-25
# 2016-03-25
# 2014-01-01
# 1999-06-08
# 1977-10-28
# 1987-04-03
# 2000-08-14
# 1983-12-01
# 2015-09-11
# 1990-01-01
# 1966-01-01
# 2006-01-01
# 2012-10-05
# 2009-01-01
# 2011-01-01
# 1967-03-10
# 1967-01-01
# 2007-01-01
# 2017-11-03
# 2009-05-15
# 2002-01-01
# 2016-09-30
# 2008-01-01
# 1981-10-02
# 2015-04-17
# 2010-07-01
# 2005-01-01
# 2018-05-04
# 1992
# 2017-06-02
# 1997-10-09
# 2013-01-01
# 2005-09-26
# 1975-05-19
# 2010-11-24
# 2011-09-23
# 1999-04-23
# 2012-01-01
# 1995-01-01
# 2012-04-02
# 1966-06-16
# 2020-05-20
# 2008-04-25
# 2017-02-23
# 2011-11-28
# 2011-08-31
# 1965
# ...

# %%
df.iloc[8:20,:]
# Out:
#                                Track URI  \
# 8   spotify:track:00qOE7OjRl0BpYiCiweZB2
# 9   spotify:track:3OalxlWH0v14kyBcNBMINt
# 10  spotify:track:0CtkjgZpkgnW7U6WmHsakD
# 11  spotify:track:3NLrRZoMF0Lx6zTlYqeIo4
# 12  spotify:track:09tyJ0VvbLty84iHIV3WQn
# 13  spotify:track:73JqQIGZUZxCVfY54RSpCH
# 14  spotify:track:6K8qKeWo5MsFED7wCR6Kop
# 15  spotify:track:3tP0kdmWRSqmJAt4nR3ykw
# 16  spotify:track:2760p399WNJLX9LGBkjL4Z
# 17  spotify:track:5yJCo7EewUcX9qj5nnk9O2
# 18  spotify:track:2uiyVyP0Rvl0MgB8ehoc07
# 19  spotify:track:2J22VgQALSoekF3KCj1nIk
#
#                                            Track Name  \
# 8                                       Juke Box Hero
# 9                                               Mercy
# 10                                     It's Like That
# 11                                   Here Without You
# 12                Listen to the Band - Single Version
# 13               With A Little Luck - Remastered 1993
# ...
